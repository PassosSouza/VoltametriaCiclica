# %%
#importando dados
import pandas as pd
#-----------------
#LiF+NaF
#----------------
data = pd.read_csv(f'M xenes 1 10mv -0,1_0,85.txt',sep=';')
V1 = data['Potential applied (V)'].values
A1 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 1 20mv -0,1_0,85.txt',sep=';')
V2 = data['Potential applied (V)'].values
A2 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 1 30mv -0,1_0,85.txt',sep=';')
V3 = data['Potential applied (V)'].values
A3 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 1 40mv -0,1_0,85.txt',sep=';')
V4 = data['Potential applied (V)'].values
A4 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 1 50mv -0,1_0,85.txt',sep=';')
V5 = data['Potential applied (V)'].values
A5 = data['WE(1).Current (A)'].values

#pegando intervalo ótimo e já colocando dividido pela massa
ii = int(len(V1)/5)
V111,A111, V221,A221,V331,A331,V441,A441,V551,A551 = [],[],[],[],[],[],[],[],[],[]
for i in range(1,6):
    V111.append(V1[ii*i:ii*(i+1)-30])
    A111.append(A1[ii*i:ii*(i+1)-30])
    
    V221.append(V2[ii*i:ii*(i+1)-30])
    A221.append(A2[ii*i:ii*(i+1)-30])
    
    V331.append(V3[ii*i:ii*(i+1)-30])
    A331.append(A3[ii*i:ii*(i+1)-30])
    
    V441.append(V4[ii*i:ii*(i+1)-30])
    A441.append(A4[ii*i:ii*(i+1)-30])
    
    V551.append(V5[ii*i:ii*(i+1)-30])
    A551.append(A5[ii*i:ii*(i+1)-30])
A121,A231,A321,A421,A521=[],[],[],[],[]
for i in range(len(V551)):
    A121.append(A111[i]-min(A111[i]))
    A231.append(A221[i] - min(A221[i]))
    A321.append(A331[i]-min(A331[i]))
    A421.append(A441[i]-min(A441[i]))
    A521.append(A551[i]-min(A551[i]))
#-----------------
#KF + NaF 
#--------------
data = pd.read_csv(f'M xenes 2 10mv -0,1_0,85_2.txt',sep=';')
V1 = data['Potential applied (V)'].values
A1 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 2 20mv -0,1_0,85_2.txt',sep=';')
V2 = data['Potential applied (V)'].values
A2 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 2 30mv -0,1_0,85.txt',sep=';')
V3 = data['Potential applied (V)'].values
A3 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 2 40mv -0,1_0,85.txt',sep=';')
V4 = data['Potential applied (V)'].values
A4 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'M xenes 2 50mv -0,1_0,85.txt',sep=';')
V5 = data['Potential applied (V)'].values
A5 = data['WE(1).Current (A)'].values

#pegando intervalo ótimo e já colocando dividido pela massa
ii = int(len(V1)/5)
ii = int(len(V1)/5)
V112,A112, V222,A222,V332,A332,V442,A442,V552,A552 = [],[],[],[],[],[],[],[],[],[]
for i in range(1,6):
    V112.append(V1[ii*i:ii*(i+1)-30])
    A112.append(A1[ii*i:ii*(i+1)-30])
    
    V222.append(V2[ii*i:ii*(i+1)-30])
    A222.append(A2[ii*i:ii*(i+1)-30])
    
    V332.append(V3[ii*i:ii*(i+1)-30])
    A332.append(A3[ii*i:ii*(i+1)-30])
    
    V442.append(V4[ii*i:ii*(i+1)-30])
    A442.append(A4[ii*i:ii*(i+1)-30])
    
    V552.append(V5[ii*i:ii*(i+1)-30])
    A552.append(A5[ii*i:ii*(i+1)-30])
A122,A232,A322,A422,A522=[],[],[],[],[]
for i in range(len(V552)):
    A122.append(A112[i]-min(A112[i]))
    A232.append(A222[i] - min(A222[i]))
    A322.append(A332[i]-min(A332[i]))
    A422.append(A442[i]-min(A442[i]))
    A522.append(A552[i]-min(A552[i]))
#-------------------
#LiF
#------------------
data = pd.read_csv(f'10mV-Mxene3_2.txt',sep=';')
V1 = data['Potential applied (V)'].values
A1 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'20mV-Mxene3_2.txt',sep=';')
V2 = data['Potential applied (V)'].values
A2 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'30mV-Mxene3_2.txt',sep=';')
V3 = data['Potential applied (V)'].values
A3 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'40mV-Mxene3_2.txt',sep=';')
V4 = data['Potential applied (V)'].values
A4 = data['WE(1).Current (A)'].values
data = pd.read_csv(f'50mV-Mxene3_2.txt',sep=';')
V5 = data['Potential applied (V)'].values
A5 = data['WE(1).Current (A)'].values

#pegando intervalo ótimo e já colocando dividido pela massa
ii = int(len(V1)/5)
ii = int(len(V1)/5)
V113,A113, V223,A223,V333,A333,V443,A443,V553,A553 = [],[],[],[],[],[],[],[],[],[]
for i in range(1,6):
    V113.append(V1[ii*i:ii*(i+1)-30])
    A113.append(A1[ii*i:ii*(i+1)-30])
    
    V223.append(V2[ii*i:ii*(i+1)-30])
    A223.append(A2[ii*i:ii*(i+1)-30])
    
    V333.append(V3[ii*i:ii*(i+1)-30])
    A333.append(A3[ii*i:ii*(i+1)-30])
    
    V443.append(V4[ii*i:ii*(i+1)-30])
    A443.append(A4[ii*i:ii*(i+1)-30])
    
    V553.append(V5[ii*i:ii*(i+1)-30])
    A553.append(A5[ii*i:ii*(i+1)-30])
A123,A233,A323,A423,A523=[],[],[],[],[]
for i in range(len(V553)):
    A123.append(A113[i]-min(A113[i]))
    A233.append(A223[i] - min(A223[i]))
    A323.append(A333[i]-min(A333[i]))
    A423.append(A443[i]-min(A443[i]))
    A523.append(A553[i]-min(A553[i]))

# %%
import numpy as np
def area_between_points(x,y):
    area = 0
    for i in range(len(x)-1):
        dx = x[i+1] - x[i]
        avg_y = abs((y[i+1] + y[i]))/2
        area += abs(dx) * avg_y
    return abs(area)

def findlocal(x,x0,u):#acha onde está x0 na lista x se ele ja foi visto no indice u
    for i in range(len(x)):
        if x[i]==x0 and i!=u:
            return i
    return u
def fin(x,x0):
    for i in range(len(x)):
        if x[i]==x0:
            return True
    return False
def newarea(x,y):
    area=0
    gone=[]
    #calcular área como retângulo que vai de um ponto até outro
    for i in range(len(x)-1):
        dx = x[i+1]-x[i]
        y1=y[findlocal(x,x[i+1],i+1)]
        y2 = y[findlocal(x,x[i],i)]
        avg_y1 = (y1-y[i+1])
        avg_y2 = (y2-y[i])
        avg_y = (abs(avg_y1)+abs(avg_y2))/2
        if fin(gone,x[i])==False:
            area+=abs(dx*avg_y)
            gone.append(x[i])
    return area

# %%
Ae11,Ae21,Ae31,Ae41,Ae51=[],[],[],[],[]
for i in range(1,len(V111)-1):
    Ae11.append(newarea(V111[i], A121[i]))
    Ae21.append(newarea(V221[i], A231[i]))
    Ae31.append(newarea(V331[i], A321[i]))
    Ae41.append(newarea(V441[i], A421[i]))
    Ae51.append(newarea(V551[i], A521[i]))
Ae111 = [np.mean(Ae11),np.mean(Ae21),np.mean(Ae31),np.mean(Ae41),np.mean(Ae51)]
eAe111 = np.array([np.std(Ae11),np.std(Ae21),np.std(Ae31),np.std(Ae41),np.std(Ae51)])/np.sqrt(len(Ae11))
#---------------
#KF+NaF
#----------------
Ae1,Ae2,Ae3,Ae4,Ae5=[],[],[],[],[]

for i in range(1,len(V112)-1):
    Ae1.append(newarea(V112[i], A122[i]))
    Ae2.append(newarea(V222[i], A232[i]))
    Ae3.append(newarea(V332[i], A322[i]))
    Ae4.append(newarea(V442[i], A422[i]))
    Ae5.append(newarea(V552[i], A522[i]))
Ae22 = [np.mean(Ae1),np.mean(Ae2),np.mean(Ae3),np.mean(Ae4),np.mean(Ae5)]
eAe22 = np.array([np.std(Ae1),np.std(Ae2),np.std(Ae3),np.std(Ae4),np.std(Ae5)])/np.sqrt(len(Ae1))
#--------------------
#LiF
#--------------------
Ae1,Ae2,Ae3,Ae4,Ae5=[],[],[],[],[]

for i in range(1,len(V113)-1):
    Ae1.append(newarea(V113[i], A123[i]))
    Ae2.append(newarea(V223[i], A233[i]))
    Ae3.append(newarea(V333[i], A323[i]))
    Ae4.append(newarea(V443[i], A423[i]))
    Ae5.append(newarea(V553[i], A523[i]))
Ae33 = [np.mean(Ae1),np.mean(Ae2),np.mean(Ae3),np.mean(Ae4),np.mean(Ae5)]
eAe33 = np.array([np.std(Ae1),np.std(Ae2),np.std(Ae3),np.std(Ae4),np.std(Ae5)])/np.sqrt(len(Ae1))

# %%
from matplotlib import pyplot as plt
csfont = {'fontname':'Times New Roman'}
hfont = {'fontname':'Times New Roman'}
import pylab as plb
plb.rcParams['font.size'] = 12
fig, axs = plt.subplots(2,3, figsize=(20,10))

axs[0,0].plot(V111[u],A111[u],'-',color = 'green',label='10 mV/s')
axs[0,0].plot(V221[u],A221[u],'-',color = 'gray',label='20 mV/s')
axs[0,0].plot(V331[u],A331[u],'-',color = 'orange',label='30 mV/s')
axs[0,0].plot(V441[u],A441[u],'-',color = 'red',label='40 mV/s')
axs[0,0].plot(V551[u],A551[u],'-',color = 'purple',label='50 mV/s')

axs[0,0].legend()
axs[0,0].set_title('A',fontweight='bold',fontsize=15)#NaF+LiF Graph 
axs[0,0].set_ylabel('Corrente (A)')
axs[0,0].set_xlabel('Voltagem (V)')

axs[0,1].plot(V112[u],A112[u],'-',color = 'green',label='Scan rate 10 mV/s')
axs[0,1].plot(V222[u],A222[u],'-',color = 'gray',label='Scan rate 20 mV/s')
axs[0,1].plot(V332[u],A332[u],'-',color = 'orange',label='Scan rate 30 mV/s')
axs[0,1].plot(V442[u],A442[u],'-',color = 'red',label='Scan rate 40 mV/s')
axs[0,1].plot(V552[u],A552[u],'-',color = 'purple',label='Scan rate 50 mV/s')

#axs[0,1].legend()
axs[0,1].set_title('B',fontweight='bold',fontsize=15)#NaF + KF Graph 
axs[0,1].set_xlabel('Voltagem (V)')
#plt.xlabel('Voltage (V)')


axs[0,2].plot(V113[u],A113[u],'-',color = 'green',label='Scan rate 10 mV/s')
axs[0,2].plot(V223[u],A223[u],'-',color = 'gray',label='Scan rate 20 mV/s')
axs[0,2].plot(V333[u],A333[u],'-',color = 'orange',label='Scan rate 30 mV/s')
axs[0,2].plot(V443[u],A443[u],'-',color = 'red',label='Scan rate 40 mV/s')
axs[0,2].plot(V553[u],A553[u],'-',color = 'purple',label='Scan rate 50 mV/s')
axs[0,2].set_title('C',fontweight='bold',fontsize=15)#LiF Graph
axs[0,2].set_xlabel('Voltagem (V)')
#------------------------------------------
#AGORA PLOTS DOS AJUSTES LINEARES
#-----------------------------------
from scipy.optimize import curve_fit
k = np.array([10,20,30,40,50])
k = k*10**(-3)
def f(x,A,B):
    return A*x+B
x=np.linspace(0,51*10**(-3),50)

popt, pcov = curve_fit(f,k,Ae111)
std = np.sqrt(np.diag(pcov))
ydata_mean = np.mean(Ae111)
SST = np.sum((Ae111 - ydata_mean)**2)
ydata_fit = f(k, *popt)
SSR = np.sum((Ae111 - ydata_fit)**2)


axs[1,0].plot(x,f(x,popt[0],popt[1]),':',label=f'Ajuste R^2 = {round(1-SSR/SST,3)}')
axs[1,0].plot(k,Ae111,'o',label='Data')
axs[1,0].errorbar(k,Ae111,yerr=eAe111,fmt='.k')

axs[1,0].legend()
axs[1,0].set_title('D',fontweight='bold',fontsize=15)#NaF+LiF (Enumerated 1) 
axs[1,0].set_xlabel('Velocidade de Varredura (V/s)')
axs[1,0].set_ylabel('Corrente (A)')


popt, pcov = curve_fit(f,k,Ae22)
std = np.sqrt(np.diag(pcov))
ydata_mean = np.mean(Ae22)
SST = np.sum((Ae22 - ydata_mean)**2)
ydata_fit = f(k, *popt)
SSR = np.sum((Ae22 - ydata_fit)**2)


axs[1,1].plot(x,f(x,popt[0],popt[1]),':',label=f'Ajuste R^2 = {round(1-SSR/SST,3)}')
axs[1,1].plot(k,Ae22,'o',label='Data')
axs[1,1].errorbar(k,Ae22,yerr=eAe22,fmt='.k')

axs[1,1].legend()
axs[1,1].set_title('E',fontweight='bold',fontsize=15)#NaF+KF (Enumerated 2) 
axs[1,1].set_xlabel('Velocidade de Varredura (V/s)')



popt, pcov = curve_fit(f,k,Ae33)
std = np.sqrt(np.diag(pcov))
ydata_mean = np.mean(Ae33)
SST = np.sum((Ae33 - ydata_mean)**2)
ydata_fit = f(k, *popt)
SSR = np.sum((Ae33 - ydata_fit)**2)


axs[1,2].plot(x,f(x,popt[0],popt[1]),':',label=f'Ajuste R^2 = {round(1-SSR/SST,3)}')
axs[1,2].plot(k,Ae33,'o',label='Data')
axs[1,2].errorbar(k,Ae33,yerr=eAe33,fmt='.k')

axs[1,2].legend()
axs[1,2].set_title('F',fontweight='bold',fontsize=15)#LiF (Enumerated 3) 
axs[1,2].set_xlabel('Velocidade de Varredura (V/s)')


plt.subplots_adjust(wspace=0.35,hspace=0.3)
plt.savefig('Figure-To-Article.png')
